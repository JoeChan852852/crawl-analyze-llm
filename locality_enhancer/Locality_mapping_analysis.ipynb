# %% [markdown]
# # Objective

# %% [markdown]
#     We are presently poring over the map with meticulous care, endeavouring to verify
#     that every entry is both accurate and wholly unique—no small task, yet an essential one.

# %%
import pandas as pd
Map = pd.read_csv('Locality_mapping.csv') # read the dataframe
Map
# Out:
#                                   District       City  \
# 0                           Suffolk County     Boston
# 1                                      NaN  Hong Kong
# 2                                Apeldoorn  Apeldoorn
# 3                                Hampshire        NaN
# 4                              Cook County    Chicago
# ..                                     ...        ...
# 262                                    NaN     Skopje
# 263                         Alameda County    Fremont
# 264                                   Agra       Agra
# 265                            Maui County        NaN
# 266  Royal Borough of Kingston upon Thames     London
#
#                                                Country      Continent  \
# 0                             United States of America  North America
# 1                                                China           Asia
# 2                                          Netherlands         Europe
# 3    United Kingdom of Great Britain and Northern I...         Europe
# 4                             United States of America  North America
# ..                                                 ...            ...
# 262                                    North Macedonia         Europe
# 263                           United States of America  North America
# 264                                              India           Asia
# 265                           United States of America  North America
# 266  United Kingdom of Great Britain and Northern I...         Europe
#
#                    locality
# 0                 Boston...
# 1          Hong Kong, China
# 2         Apeldoorn, The...
# 3    New Forest National...
# 4         Chicago, Illinois
# ..                      ...
# 262  Skopje, Republic of...
# 263     Fremont, California
# 264             Agra, India
# 265           Kihei, Hawaii
# 266     Surbiton, United...
#
# [267 rows x 5 columns]

# %%
Map['Country'][154] = "Malaysia"
# Out:
# /tmp/ipykernel_32705/3622963244.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Map['Country'][154] = "Malaysia"

# %%
Map
# Out:
#                                   District       City  \
# 0                           Suffolk County     Boston
# 1                                      NaN  Hong Kong
# 2                                Apeldoorn  Apeldoorn
# 3                                Hampshire        NaN
# 4                              Cook County    Chicago
# ..                                     ...        ...
# 262                                    NaN     Skopje
# 263                         Alameda County    Fremont
# 264                                   Agra       Agra
# 265                            Maui County        NaN
# 266  Royal Borough of Kingston upon Thames     London
#
#                                                Country      Continent  \
# 0                             United States of America  North America
# 1                                                China           Asia
# 2                                          Netherlands         Europe
# 3    United Kingdom of Great Britain and Northern I...         Europe
# 4                             United States of America  North America
# ..                                                 ...            ...
# 262                                    North Macedonia         Europe
# 263                           United States of America  North America
# 264                                              India           Asia
# 265                           United States of America  North America
# 266  United Kingdom of Great Britain and Northern I...         Europe
#
#                    locality
# 0                 Boston...
# 1          Hong Kong, China
# 2         Apeldoorn, The...
# 3    New Forest National...
# 4         Chicago, Illinois
# ..                      ...
# 262  Skopje, Republic of...
# 263     Fremont, California
# 264             Agra, India
# 265           Kihei, Hawaii
# 266     Surbiton, United...
#
# [267 rows x 5 columns]

# %% [markdown]
#     We have observed that certain entities appear under multiple guises within the dataset—most notably,
#     “United States of America” alongside the abbreviated “United States”, and “United Kingdom of Great
#     Britain and Northern Ireland” juxtaposed with the more concise “United Kingdom”. Such heterogeneity
#     is, frankly, rather untidy. Accordingly, we must now undertake a thorough cleansing of the dataset
#     to enforce rigorous consistency and homogeneity across all such entries.

# %%
Map.drop_duplicates(subset=['Country'])
# Out:
#                   District              City  \
# 0           Suffolk County            Boston
# 1                      NaN         Hong Kong
# 2                Apeldoorn         Apeldoorn
# 3                Hampshire               NaN
# 5                      NaN               NaN
# 7                      NaN               NaN
# 8                  Unknown             Tokyo
# 9                  Unknown             Paris
# 10                 Unknown         Bucharest
# 16          City of Sydney            Sydney
# 17                     NaN               NaN
# 37        Hua Hin District           Hua Hin
# 38                     NaN      Johannesburg
# 41                     NaN            Manila
# 45                     NaN           Seville
# 49            Business Bay             Dubai
# 51         Bengaluru Urban         Bengaluru
# 61                Tel Aviv     Tel Aviv-Yafo
# 69                     NaN           Jakarta
# 72                 Unknown             Cairo
# 73                     NaN      Kuala Lumpur
# 75                     NaN               NaN
# 79                  Cervia  Milano Marittima
# 90     Kiruna Municipality            Kiruna
# 93                 Unknown            Vienna
# 117                    NaN               NaN
# 120                Antalya           Antalya
# 123                    NaN          Budapest
# 126          County Dublin            Dublin
# 130                    NaN      Buenos Aires
# 135                    NaN           Hamburg
# 145                    NaN            Jeddah
# 146    Capital Governorate       Kuwait City
# 194                    NaN             Hanoi
# 213                    NaN          Helsinki
# 217                    NaN         Volgograd
# 218                    NaN               NaN
# 225                    NaN               NaN
# 232  Osijek-Baranja County             Čepin
# 261             Sermersooq  Ittoqqortoormiit
# 262                    NaN            Skopje
#
#                                                Country      Continent  \
# 0                             United States of America  North America
# 1                                                China           Asia
# 2                                          Netherlands         Europe
# 3    United Kingdom of Great Britain and Northern I...         Europe
# 5                                               Canada  North America
# 7                                            Singapore           Asia
# 8                                                Japan           Asia
# 9                                               France         Europe
# 10                                             Romania         Europe
# 16                                           Australia      Australia
# 17                                         New Zealand      Australia
# 37                                            Thailand           Asia
# 38                                        South Africa         Africa
# 41                                         Philippines           Asia
# 45                                               Spain         Europe
# 49                                United Arab Emirates           Asia
# 51                                               India           Asia
# 61                                              Israel           Asia
# 69                                           Indonesia           Asia
# 72                                               Egypt         Africa
# 73                                            Malaysia           Asia
# 75                                              Greece         Europe
# 79                                               Italy         Europe
# 90                                              Sweden         Europe
# 93                                             Austria         Europe
# 117                                            Georgia         Europe
# 120                                            Türkiye           Asia
# 123                                            Hungary         Europe
# 126                                            Ireland         Europe
# 130                                          Argentina  South America
# 135                                            Germany         Europe
# 145                                       Saudi Arabia           Asia
# 146                                             Kuwait           Asia
# 194                                           Viet Nam           Asia
# 213                                            Finland         Europe
# 217                                 Russian Federation         Europe
# 218                                            Unknown         Europe
# 225                                              Malta         Europe
# 232                                            Croatia         Europe
# 261                                            Denmark  North America
# 262                                    North Macedonia         Europe
#
#                    locality
# 0                 Boston...
# 1          Hong Kong, China
# 2         Apeldoorn, The...
# 3    New Forest National...
# 5                    Canada
# 7      Singapore, Singapore
# 8              Tokyo, Japan
# 9             Paris, France
# 10       Bucharest, Romania
# 16        Sydney, Australia
# 17              New Zealand
# 37        Hua Hin, Thailand
# 38   Johannesburg, South...
# 41      Manila, Philippines
# 45           Seville, Spain
# 49          Business Bay...
# 51         Bengaluru, India
# 61         Tel Aviv, Israel
# 69       Jakarta, Indonesia
# 72             Cairo, Egypt
# 73          Kuala Lumpur...
# 75                   Greece
# 79      Milano Marittima...
# 90           Kiruna, Sweden
# 93          Vienna, Austria
# 117                 Georgia
# 120        Antalya, Turkiye
# 123       Budapest, Hungary
# 126         Dublin, Ireland
# 130         Buenos Aires...
# 135        Hamburg, Germany
# 145    Jeddah, Saudi Arabia
# 146     Kuwait City, Kuwait
# 194          Hanoi, Vietnam
# 213       Helsinki, Finland
# 217       Volgograd, Russia
# 218                  Europe
# 225           Malta, Europe
# 232          Cepin, Croatia
# 261     Ittoqqortoormiit...
# 262  Skopje, Republic of...

# %%
Map['Country'] = Map['Country'].replace('United Kingdom of Great Britain and Northern Ireland', 'United Kingdom')
Map['Country'] = Map['Country'].replace('England', 'United Kingdom')
Map['Country'] = Map['Country'].replace('United States of America', 'United States')
Map['Country'] = Map['Country'].replace('People’s Republic of China', 'China')
Map['Continent'] = Map['Continent'].replace('Australia', 'Oceania')

# %%
Map.drop_duplicates(subset=['Country']).reset_index(drop=True)
# Out:
#     Unnamed: 0                      District              City  \
# 0            0                       Suffolk            Boston
# 1            1                           NaN         Hong Kong
# 2            2                    Gelderland         Apeldoorn
# 3            3                     Hampshire               NaN
# 4            5                           NaN               NaN
# 5            7                           NaN               NaN
# 6            8                           NaN             Tokyo
# 7            9                           NaN             Paris
# 8           10          Sectors of Bucharest         Bucharest
# 9           16                City of Sydney            Sydney
# 10          17                           NaN               NaN
# 11          33                 County Dublin            Dublin
# 12          37                       Hua Hin               NaN
# 13          38                      Region F      Johannesburg
# 14          41             16 City Districts            Manila
# 15          45                           NaN           Seville
# 16          49                           NaN             Dubai
# 17          51               Bengaluru Urban         Bengaluru
# 18          61                      Tel Aviv     Tel Aviv-Yafo
# 19          69               Central Jakarta           Jakarta
# 20          72                       Zamalek             Cairo
# 21          75                           NaN               NaN
# 22          77                           NaN               NaN
# 23          79                           NaN  Milano Marittima
# 24          90           Kiruna Municipality            Kiruna
# 25          93                           NaN            Vienna
# 26         115           Metro Manila region       Makati City
# 27         117                           NaN               NaN
# 28         120                           NaN           Antalya
# 29         123                          Buda          Budapest
# 30         130                      Recoleta      Buenos Aires
# 31         135                           NaN           Hamburg
# 32         145                           NaN            Jeddah
# 33         146           Capital Governorate       Kuwait City
# 34         194                     Hoàn Kiếm             Hanoi
# 35         202  Central and Western District         Hong Kong
# 36         213                           NaN          Helsinki
# 37         217                           NaN         Volgograd
# 38         218                           NaN               NaN
# 39         225                           NaN               NaN
# 40         232         Osijek-Baranja County             Čepin
# 41         261                           NaN  Ittoqqortoormiit
# 42         262                           NaN            Skopje
#
#                        Country      Continent                locality
# 0                United States  North America               Boston...
# 1                        China           Asia        Hong Kong, China
# 2                  Netherlands         Europe       Apeldoorn, The...
# 3               United Kingdom         Europe  New Forest National...
# 4                       Canada  North America                  Canada
# 5                    Singapore           Asia    Singapore, Singapore
# 6                        Japan           Asia            Tokyo, Japan
# 7                       France         Europe           Paris, France
# 8                      Romania         Europe      Bucharest, Romania
# 9                    Australia        Oceania       Sydney, Australia
# 10                 New Zealand        Oceania             New Zealand
# 11                     Ireland         Europe      Dublin, California
# 12                    Thailand           Asia       Hua Hin, Thailand
# 13                South Africa         Africa  Johannesburg, South...
# 14                 Philippines           Asia     Manila, Philippines
# 15                       Spain         Europe          Seville, Spain
# 16        United Arab Emirates           Asia         Business Bay...
# 17                       India           Asia        Bengaluru, India
# 18                      Israel           Asia        Tel Aviv, Israel
# 19                   Indonesia           Asia      Jakarta, Indonesia
# 20                       Egypt         Africa            Cairo, Egypt
# 21                      Greece         Europe                  Greece
# 22                    Malaysia           Asia                Malaysia
# 23                       Italy         Europe     Milano Marittima...
# 24                      Sweden         Europe          Kiruna, Sweden
# 25                     Austria         Europe         Vienna, Austria
# 26                Philippines            Asia                  makati
# 27                     Georgia         Europe                 Georgia
# 28                      Turkey           Asia        Antalya, Turkiye
# 29                     Hungary         Europe       Budapest, Hungary
# 30                   Argentina  South America         Buenos Aires...
# 31                     Germany         Europe        Hamburg, Germany
# 32                Saudi Arabia           Asia    Jeddah, Saudi Arabia
# 33                      Kuwait           Asia     Kuwait City, Kuwait
# 34                    Viet Nam           Asia          Hanoi, Vietnam
# 35  People's Republic of China           Asia               Hong Kong
# 36                     Finland         Europe       Helsinki, Finland
# 37          Russian Federation         Europe       Volgograd, Russia
# 38                     Unknown         Europe                  Europe
# 39                       Malta         Europe           Malta, Europe
# 40                     Croatia         Europe          Cepin, Croatia
# 41                     Denmark  North America     Ittoqqortoormiit...
# 42             North Macedonia         Europe  Skopje, Republic of...

# %%
Map.drop_duplicates(subset=['Continent']).reset_index(drop=True)
# Out:
#          District          City                   Country      Continent  \
# 0  Suffolk County        Boston  United States of America  North America
# 1             NaN     Hong Kong                     China           Asia
# 2       Apeldoorn     Apeldoorn               Netherlands         Europe
# 3  City of Sydney        Sydney                 Australia      Australia
# 4             NaN  Johannesburg              South Africa         Africa
# 5             NaN  Buenos Aires                 Argentina  South America
# 6         Unknown       Unknown                   Unknown        Unknown
#
#                  locality
# 0               Boston...
# 1        Hong Kong, China
# 2       Apeldoorn, The...
# 3       Sydney, Australia
# 4  Johannesburg, South...
# 5         Buenos Aires...
# 6                   jtang

# %% [markdown]
#     Now, having removed the duplicates, we can be confident that we no longer have alternative
#     spellings or variant names for the same country or continent.

# %%
Map.to_csv('Locality_mapping_2025-12-20.csv', index=False)
