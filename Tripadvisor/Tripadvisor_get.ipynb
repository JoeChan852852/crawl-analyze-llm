# %%
import pandas as pd
import WebCrawler
Topics = pd.read_csv('Topics.csv')

# %%
Topics["Topics"][0]
# Out:
# '/ShowTopic-g294217-i1496-k14870207-Happy_Valley_race_day_packages-Hong_Kong.html'

# %%
Topics["Topics"][1]
# Out:
# '/ShowTopic-g294217-i1496-k14819843-Hong_Kong_Horse_Racing-Hong_Kong.html'

# %%
Topics["Topics"][2]
# Out:
# '/ShowTopic-g294217-i1496-k14869107-Help_Tips_for_my_16_full_days_in_Hong_Kong-Hong_Kong.html'

# %%
target = "https://en.tripadvisor.com.hk/ShowTopic-g294217-i1496-k14920794-Layover_Itinerary-Hong_Kong.html"
HTML_name = "test.html"
WebCrawler.HTML_get(target,HTML_name)
# Out:
#
# VPN is down.
#
# Starting VPN
#
# 0 TCP
# 1 UDP
# 1 selected
# ls -l
# Checking for connection status...
# Connected to Surfshark VPN
# Your new IP: 156.146.45.114
# Received/Sent: 34 kB/27 kB
# Received/Sent: 34 kB/27 kB
#
# ---------------------------------------------------------------
# Cookies captured: 18
#
# VPN is down.
